# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#pip install mpld3

# %%
# %matplotlib notebook
import mpld3
mpld3.enable_notebook()

# %%
x1 = np.linspace(0,10,1000)
y = np.dot(x1*x1,5)

# %%
#np.shape(y)
# Out:
# (1000,)

# %%
plt.plot(x1,y,".")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.shape(y)
# Out:
# (1000,)

# %%
#Let N be the number of points
N = 800
i = 0+1j
#k = np.linspace(0,10,N-1)

# %%
#w = np.sum(2*np.pi*k)

# %%
final = []
complex_expo = 0
#np.array(complex_expo)
np.array(final)
for k in range(0,1000):
    for n in range(0,1000):
        complex_expo = complex_expo + y[k]*np.exp(-(2*np.pi*i*k*n)/N)
    final = np.append(final,complex_expo)

# %%
print(np.shape(final))
# Out:
# (1000,)

# %%
fig, ax = plt.subplots()
plt.plot(final.real, final.imag)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
back = []
inv_complex_expo = 0
np.array(back)
for k in range(0,1000):
    for n in range(0,1000):
        inv_complex_expo =inv_complex_expo + final[k]*np.exp((2*np.pi*i*k*n)/N)
    back = np.append(back,inv_complex_expo)

# %%
np.shape(back)
# Out:
# (1000,)

# %%
fig2, bx = plt.subplots()
plt.plot(back.real, back.imag)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.subplot(1,3,1)
plt.plot(x1,y,'.')
plt.subplot(1,3,2)
plt.plot(final.real, final.imag)
plt.subplot(1,3,3)
plt.plot(back.real, back.imag)
# Out:
# <img src="data:image/png;base64,..." width="640">
